# %% [markdown]
# # **Sample Data Folder** 📂
#
# We've included sample images to use as input for **`infer-subc`** from recent work in the Sarah Cohen Lab.

# %% [markdown]
# ## **Which sample data should you use?**

# %% [markdown]
# There are several different example images to choose from below. They are all multi-channel confocal microscopy images containing a single channel for the lysosomes, mitohcondria, Golgi, peroxisomes, ER, and lipid droplets. Each example utilizes a different masks (cell/nucleus) segmentation workflow and some include example soma/neurites segmentations. If you know what type of data you would be using for your analysis, you can choose the sample data that most closely matches your data. Here is more information about each sample image:
#
#
# **Sample data specifications**
#
# | **Sample image name:**            | pri-neuron        | pri-astrocyte     | iNeuron           | iPSC
# |:---                               | :---              | :---              | :---              | :---
# | **Mask workflow used:**           | masks_A           | masks_B           | masks_C           | masks_D
# | **Includes soma/neurites?**       | No                | No                | Yes               | No
# | **BioImage Archive Accession #:** | [S-BIAD1445](https://www.ebi.ac.uk/biostudies/BioImages/studies/S-BIAD1445) | [S-BIAD1445](https://www.ebi.ac.uk/biostudies/BioImages/studies/S-BIAD1445) | [S-BIAD3209](https://www.ebi.ac.uk/biostudies/bioimages/studies/S-BIAD3209?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d) | [S-BIAD2983](https://www.ebi.ac.uk/biostudies/bioimages/studies/S-BIAD2983)
# | **Publication:**           | [PMID: 40956669](https://doi.org/10.1016/j.celrep.2025.116280) | [PMID: 40956669](https://doi.org/10.1016/j.celrep.2025.116280) | [doi: https://doi.org/10.64898/2026.04.13.718193](https://www.biorxiv.org/content/10.64898/2026.04.13.718193v1) | [doi: https://doi.org/10.64898/2026.02.10.704675](https://www.biorxiv.org/content/10.64898/2026.02.10.704675v1)
#
# ⚠️ ***REMINDER**: You do not need to use/download all of the sample data options -- choose your favorite.*

# %% [markdown]
# ## **Sample data setup:**

# %% [markdown]
# ### **`Step 1:` Clone the infer-subc repository**
#
# To use the sample data, you will first need to clone the entire infer-subc repository onto your local computer.

# %% [markdown]
# ### **`Step 2:` Download sample data for Part 1: Segmentation**
# The following steps are necessary to access the raw sample data files used in segmentation workflows:

# %% [markdown]
# 1. Run the following cell to create the necessary sample data folders within your repositories. The following folders will be created:
#     - `infer-subc/sample_data/example_{celltype}/raw` <-- location to store the downloaded raw data (see step 2-2 below)
#     - `infer-subc/sample_data/example_{celltype}/seg` <-- location to store the segmentation files created while testing part 1 workflows or downloaded (see step 3 below)
#     - `infer-subc/sample_data/example_{celltype}/quant` <-- location to store the quantification files created while testing part 2

# %%
# imports
from infer_subc.core.file_io import (sample_dirs)

# Create the subfolders needed to use the sample data folder
sample_dirs(create = True)

# %% [markdown]
# 2. Download the raw image for the sample data you would like to use. ***Note**: the links below will automatically initiate a download of the specified data. If you do not wish to download using these links, you can access the specific repository above and find the image with the same name.*
#     - Example Pri-Neuron File: [20230727_C2-121_unconditioned_well 10_cell 4_25nM TG_Linear unmixing_0_cmle.ome.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_deconvolution/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome.tiff) (💾 2.16 GB)
#     - Example Pri-Astrocyte File: [05052022_astro_control_2_Linear unmixing_0_cmle.ome.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_deconvolution/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome.tiff) (💾 1.14 GB)
#     - Example iNeuron File: [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Deconvolution/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d) (💾 0.711 GB)
#     - Example iPSC File: [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Deconvolved/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome.tiff) (💾 0.88 GB)
# 3. Move the downloaded .tiff image to the correspondingly named `infer-subc/sample_data/example_{celltype}/raw` directory.
#
# *These files are now ready to used in the [Napari plugin](/infer-subc/README.md) (see README.md for setup information) or the [segmentation workflows](/infer-subc/notebooks/part_1_segmentation_workflows/). We have provided optimized segmentation settings for each set of sample data in the settings '.json' files in the `infer-subc/sample_data/example_{celltype}/settings` folder.*

# %% [markdown]
# ### **`Step 3:` Set up for Part 2: Quantification**
#
# If you intend to use the sample data to test the quantification pipelines in Part 2, carry out one of the two options:
#
# 1. **Option 1**: Download the following segmentation files for your selected sample data and ove these files into the associated `infer-subc/sample_data/example_{celltype}/final_seg` folder for the sample data you have chosen. ***Note**: the links below will automatically initiate a download of the specified data. If you do not wish to download using these links, you can access the specific repository above and find the image with the same name.*
#     - example_pri-neuron:
#         - [20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-ER.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-ER.tiff) (💾 193.8 MB)
#         - [20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-golgi.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-golgi.tiff) (💾 193.8 MB)
#         - [20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-LD.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-LD.tiff) (💾 193.8 MB)
#         - [20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-lyso.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-lyso.tiff) (💾 193.8 MB)
#         - 20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-masks_A.tiff (originally seperated into nucleus and cellmask)
#             - [nucleus](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-nuc.tiff) (💾 193.8 MB)
#             - [cellmask](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-cell.tiff) (💾 193.8 MB)
#         - [20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-mito.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-mito.tiff) (💾 193.8 MB)
#         - [20230727_C2-121_conditioned_well 4_cell 3_untreated_Linear unmixing_0_cmle.ome-perox.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20neuron%20data/Z-stacks/replicate3_C2-121/C2-121_segmentations/20230727_C2-121_conditioned_well%204_cell%203_untreated_Linear%20unmixing_0_cmle.ome-perox.tiff) (💾 193.8 MB)
#     - example_pri-astrocyte:
#         - [05052022_astro_control_2_Linear unmixing_0_cmle.ome-ER.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-ER.tiff) (💾 102.6 MB)
#         - [05052022_astro_control_2_Linear unmixing_0_cmle.ome-golgi.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-golgi.tiff) (💾 102.6 MB)
#         - [05052022_astro_control_2_Linear unmixing_0_cmle.ome-LD.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-LD.tiff) (💾 102.6 MB)
#         - [05052022_astro_control_2_Linear unmixing_0_cmle.ome-lyso.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-lyso.tiff) (💾 102.6 MB)
#         - 05052022_astro_control_2_Linear unmixing_0_cmle.ome-masks_B.tiff (originally seperated into nucleus and cellmask)
#             - [nucleus](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-nuc.tiff) (💾 205.2 MB)
#             - [cellmask](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-cell.tiff) (💾 205.2 MB)
#         - [05052022_astro_control_2_Linear unmixing_0_cmle.ome-mito.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-mito.tiff) (💾 102.6 MB)
#         - [05052022_astro_control_2_Linear unmixing_0_cmle.ome-perox.tiff](https://www.ebi.ac.uk/biostudies/files/S-BIAD1445/Neuron%20and%20astrocyte%20organelle%20signatures%20dataset/Primary%20rat%20astrocyte%20data/Z-stacks/replicate2_VD-0505/VD-0505_segmentations/05052022_astro_control_2_Linear%20unmixing_0_cmle.ome-perox.tiff) (💾 102.6 MB)
#     - example_iNeuron:
#         - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-ER.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-ER.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#         - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-golgi.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-golgi.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#         - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-LD.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-LD.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#         - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-lyso.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-lyso.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#         - 20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-masks_C.tiff  (originally seperated into nucleus and cellmask)
#             - [20240118_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-cell.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-cell.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d) which was further separated into:
#                 - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-neurites.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-neurites.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#                 - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-soma.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-soma.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#             - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-nuc.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-nuc.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#         - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-mito.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-mito.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#         - [20240201_iN D7 TRC1 ctrl_Z 9_Linear unmixing_0_cmle.ome-perox.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/.private/f4/f5cb70-4a84-4fe4-900d-e828eea5fa7d/S-BIAD/209/S-BIAD3209/Files/Day7_iNeurons_TTLL1_MSI/Segmentations/20240201_iN%20D7%20TRC1%20ctrl_Z%209_Linear%20unmixing_0_cmle.ome-perox.tiff?key=f4f5cb70-4a84-4fe4-900d-e828eea5fa7d)
#     - example_iPSC
#         - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-ER.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-ER.tiff)
#         - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-golgi.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-golgi.tiff)
#         - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-LD.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-LD.tiff)
#         - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-lyso.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-lyso.tiff)
#         - 01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-masks_D.tiff (originally seperated into nucleus and cellmask)
#             - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-cell.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-cell.tiff)
#             - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-nuc.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-nuc.tiff)
#         - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-mito.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-mito.tiff)
#         - [01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-perox.tiff](https://ftp.ebi.ac.uk/pub/databases/biostudies/S-BIAD/983/S-BIAD2983/Files/BioImageArchive-mcz/iPSCs/Segmentation/01202024_MSi08L_iPSCs_undiff_BR5_N14_Unmixing_0_cmle.ome-perox.tiff)
# 2. **Option 2**: Use the segmentation files generated while testing Part 1 with the sample data selected above. The final segmentation files that will be used in Part 2 should be included in the `infer-subc/sample_data/example_{celltype}/final_seg` directory. If you do not have files in this directory or this directory is missing, be sure you have generated an output from each of the segmentation workflows associated to your chosen sample data (see table above) and run the [quality_check_segmentation.ipynb](/infer-subc/notebooks/part_1_segmentation_workflows/quality_check_segmentations.ipynb) notebook.
#
# *These files are now ready to use in the [quantification pipelines](/infer-subc/notebooks/part_2_quantification/). The quantification notebooks will assist you in choosing the correct quantification settings and file paths for the sample data.*

# %% [markdown]
# ----------
# ### **Happy analyzing** 🔎📊🧐
#
# You can now return to the general instructions in the infer-subc [README](/infer-subc/README.md).
