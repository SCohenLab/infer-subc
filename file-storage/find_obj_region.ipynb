# %% [markdown]
# PSEUDO CODE PLAN:
#
# Using method for finding label of orgs in an interaction, do the same for orgs in a region or interactions in a region
#
# Iterate across rows in the props table:
# Use "slice" column in table to determine numpy coordinates that obj is located at
#
# regions = []
# for index, l in enumerate(props["label"]):
#     volume = labels[props["slice"][index]]
#     lreg = mask[props["slice"][index]]
#     volume = volume==l
#     lreg = lreg[volume]
#     all_inv = np.unique(lreg[lreg>0]).tolist()
#     if len(all_inv) != 1:
#         print(f"we have an error.  as-> {all_inv}")
#     regions.append(f"{region_name}-{all_inv[0]}")
